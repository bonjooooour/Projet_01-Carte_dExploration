# %%
import pandas as pd

FIT_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/FIT--CSV-data.csv"


def function(file):

    df = pd.read_csv(file)

    # Impression de la première ligne hors titres
    line = df.iloc[0]

    # élément de la première ligne, deuxième colonne
    element = df.iloc[0,1]
  
    # nombre de lignes hors titre
    number = len(df)
    
    print(line)
    print("\n")
    print(element)
    print("\n")
    print(number)


function(FIT_file)

# %%
import pandas as pd

FIT_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/FIT--CSV-data.csv"


def function2(file):

    df = pd.read_csv(file)

    # Impression de la première ligne hors titres
    line_1 = df.iloc[0]

    # élément de la première ligne, deuxième colonne
    element = df.iloc[0,1]
  
    # nombre de lignes hors titre
    total_number = len(df)

    # dernière ligne de df
    last_element = df.iloc[total_number - 1]
    
    print(line_1)
    print("\n")
    print(element)
    print("\n")
    print(total_number)
    print("\n")
    print(last_element)

function2(FIT_file)

# %%
import pandas as pd

FIT_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/FIT--CSV-data.csv"



df = pd.read_csv(FIT_file)



# Impression de la première ligne hors titres
line_1 = df.iloc[0]

# élément de la première ligne, deuxième colonne
element = df.iloc[0,1]

# nombre de lignes hors titre
total_number = len(df)

# dernière ligne de df
last_element = df.iloc[total_number - 1]

print(line_1)
print("\n")
print(element)
print("\n")
print(total_number)
print("\n")
print(last_element)
df

for row in df.itertuples():
    print(row.distance, row.timestamp)

# %%
new_df = df.filter(["distance"])
new_df

for row in new_df.itertuples():
    print(row.distance)

# %% [markdown]
# ***

# %% [markdown]
# csv FIT --> correct CSV
#
# Fonction pour formater les CSV après conversion .fit --> CSV
#
# Format de sortie :
# Nom, Date, Latitutde, Longitude

# %%
import pandas as pd
import os

FIT_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/FIT--CSV-data.csv"
output_folder = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST"


def function_3(file, output_folder):
    df = pd.read_csv(file)
    file_name = os.path.basename(file)

    data_list = []
    count = 0
    for row in df.itertuples():
        if pd.notnull(row.position_lat) and pd.notnull(row.position_long):
            count += 1
            date, y = row.timestamp.split(' ',1)
            data_list.append({
                "nom": file_name + str(count),
                "date": date,
                "latitude": row.position_lat,
                "longitude": row.position_long
            })
    new_df = pd.DataFrame(data_list)

    output_file = os.path.join(output_folder, file_name)

    new_df.to_csv(output_folder + "/" + "format" + file_name, index=False, encoding="utf-8")

    print(f"le dataframe a bien été créé : {new_df}")


function_3(FIT_file, output_folder)
# Out:
# le dataframe a bien été créé :                       nom        date     latitude   longitude
# 0      FIT--CSV-data.csv1  2023-09-29  583251508.0  26041057.0
# 1      FIT--CSV-data.csv2  2023-09-29  583251866.0  26042704.0
# 2      FIT--CSV-data.csv3  2023-09-29  583253280.0  26042934.0
# 3      FIT--CSV-data.csv4  2023-09-29  583254391.0  26043316.0
# 4      FIT--CSV-data.csv5  2023-09-29  583255657.0  26044182.0
# ..                    ...         ...          ...         ...
# 378  FIT--CSV-data.csv379  2023-09-29  583245220.0  25992858.0
# 379  FIT--CSV-data.csv380  2023-09-29  583245448.0  25995240.0
# 380  FIT--CSV-data.csv381  2023-09-29  583245695.0  25997002.0
# 381  FIT--CSV-data.csv382  2023-09-29  583245930.0  25998591.0
# 382  FIT--CSV-data.csv383  2023-09-29  583246875.0  26000796.0
#
# [383 rows x 4 columns]

# %% [markdown]
# ***

# %% [markdown]
# csv GPX --> correct CSV
#
# Fonction pour formater les CSV après conversion .gpx --> CSV
#
# Format de sortie :
# Nom, Date, Latitutde, Longitude

# %%
import pandas as pd
import os

GPX_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/GPX--CSV-data.csv"
output_folder = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST"


def function_4(file, output_folder):
    df = pd.read_csv(file)
    file_name = os.path.basename(file)

    data_list = []
    count = 0
    for row in df.itertuples():
        count += 1
        date, y = row.time.split(' ',1)
        data_list.append({
            "nom": file_name + str(count),
            "date": date,
            "latitude": row.latitude,
            "longitude": row.longitude
        })
    new_df = pd.DataFrame(data_list)

    output_file = os.path.join(output_folder, file_name)

    new_df.to_csv(output_folder + "/" + "format" + file_name, index=False, encoding="utf-8")

    print(f"le dataframe a bien été créé : {new_df}")


function_4(GPX_file, output_folder)
# Out:
# le dataframe a bien été créé :                       nom        date   latitude  longitude
# 0      GPX--CSV-data.csv1  2023-05-17  45.556241 -73.624480
# 1      GPX--CSV-data.csv2  2023-05-17  45.556382 -73.624428
# 2      GPX--CSV-data.csv3  2023-05-17  45.556443 -73.624455
# 3      GPX--CSV-data.csv4  2023-05-17  45.556504 -73.624482
# 4      GPX--CSV-data.csv5  2023-05-17  45.556564 -73.624510
# ..                    ...         ...        ...        ...
# 564  GPX--CSV-data.csv565  2023-05-17  45.573035 -73.643900
# 565  GPX--CSV-data.csv566  2023-05-17  45.573013 -73.643894
# 566  GPX--CSV-data.csv567  2023-05-17  45.572975 -73.643875
# 567  GPX--CSV-data.csv568  2023-05-17  45.572963 -73.643864
# 568  GPX--CSV-data.csv569  2023-05-17  45.572963 -73.643864
#
# [569 rows x 4 columns]

# %%
import pandas as pd
import os

GPX_file = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST/GPX--CSV-data.csv"
output_folder = "/Users/mgerenius/VScode_Workspace/Projet_01-Carte_dExploration/data/00_DATA_TEST"


def function_4(file, output_folder):
    df = pd.read_csv(file)
    file_name = os.path.basename(file)

    data_list = []
    count = 0
    for row in df.itertuples():
        count += 1
        date, y = row.time.split(' ',1)
        data_list.append(
            {
            "nom": file_name + str(count),
            "date": date,
            "latitude": row.latitude,
            "longitude": row.longitude
            }
        )


    new_df = pd.DataFrame(data_list)
    new_df.to_csv(file, index=False, encoding="utf-8")

    print(f"le dataframe a bien été créé : {new_df}")
    print(f"Le fichier a été stocké ici : \n{file}")



function_4(GPX_file, output_folder)
